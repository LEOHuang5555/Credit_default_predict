# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import roc_curve, roc_auc_score, auc, confusion_matrix
import seaborn as sns
import sqlite3

# %%
attr = pd.read_excel('CCRQM_NCHU_衡量變數.xlsx')
data = pd.read_csv('dfdata_補值 (1).csv', encoding='big5')

# %%
# data = data.fillna(0)
data
# Out:
#          公司碼        財報年月   A104   A105   A106   A109   A111  A115    A116  \
# 0          2  2014-12-01  16.15  29.94  14.65  13.25  28.67  3.83   69.29
# 1          2  2015-12-01  20.71  28.66  14.50  13.43   8.31  4.88   63.30
# 2          2  2016-12-01  19.16  28.90  14.23  11.89  16.60  4.17   63.86
# 3          2  2017-12-01  20.92  33.71  18.75  15.49  34.28  3.92   77.07
# 4          2  2018-12-01  23.06  37.14  22.77  16.74  11.42  4.02   72.33
# ...      ...         ...    ...    ...    ...    ...    ...   ...     ...
# 9144  600856  2015-12-01  17.30  21.20  16.94  14.75   3.64  9.80   57.71
# 9145  600856  2016-12-01  15.20  27.15  17.31  13.97   9.57  6.76   27.33
# 9146  600856  2017-12-01  14.20  23.64  16.88  11.95  10.67  6.93   64.34
# 9147  600857  2014-12-01   4.46  11.15   2.86   3.52   2.17  3.36  156.46
# 9148  600857  2015-12-01   3.71  11.74   2.80   4.02   2.63  2.87   79.43
#
#        A140  ...  XPYR     財報年月_r$   產業碼    產業名    year  上市板塊  是否違約   原因  \
# ...

# %%
non_na_index = data['是否違約'].dropna().index
data = data.loc[non_na_index]
data
# Out:
#          公司碼        財報年月   A104   A105   A106   A109   A111   A115    A116  \
# 0          2  2014-12-01  16.15  29.94  14.65  13.25  28.67   3.83   69.29
# 1          2  2015-12-01  20.71  28.66  14.50  13.43   8.31   4.88   63.30
# 2          2  2016-12-01  19.16  28.90  14.23  11.89  16.60   4.17   63.86
# 3          2  2017-12-01  20.92  33.71  18.75  15.49  34.28   3.92   77.07
# 4          2  2018-12-01  23.06  37.14  22.77  16.74  11.42   4.02   72.33
# ...      ...         ...    ...    ...    ...    ...    ...    ...     ...
# 9143  600856  2014-12-01  28.70  24.48  20.10  47.68  58.73  15.50   50.70
# 9144  600856  2015-12-01  17.30  21.20  16.94  14.75   3.64   9.80   57.71
# 9145  600856  2016-12-01  15.20  27.15  17.31  13.97   9.57   6.76   27.33
# 9146  600856  2017-12-01  14.20  23.64  16.88  11.95  10.67   6.93   64.34
# 9147  600857  2014-12-01   4.46  11.15   2.86   3.52   2.17   3.36  156.46
#
# ...

# %% [markdown]
# ## Drop nan
# 僅保留沒有NA值的columns

# %%
col_na = data.apply(lambda x:x.isna().sum())
# col_na[col_na<len(data)*0.1].sort_values(ascending=False)
non_na_col = col_na[col_na==0].index
data = data.loc[:,non_na_col]
data
# Out:
#          公司碼        財報年月   A105   A106    A116    A401    A509  A511  A517  \
# 0          2  2014-12-01  29.94  14.65   69.29    9.03  101.74   0.0  1.08
# 1          2  2015-12-01  28.66  14.50   63.30   31.97  113.69   0.0  0.97
# 2          2  2016-12-01  28.90  14.23   63.86   23.41  144.92   0.0  0.97
# 3          2  2017-12-01  33.71  18.75   77.07    0.73  189.57   0.0  1.69
# 4          2  2018-12-01  37.14  22.77   72.33   22.60  215.13   0.0  2.78
# ...      ...         ...    ...    ...     ...     ...     ...   ...   ...
# 9143  600856  2014-12-01  24.48  20.10   50.70  235.27   78.80   0.0  3.09
# 9144  600856  2015-12-01  21.20  16.94   57.71   65.01   60.94   0.0  2.74
# 9145  600856  2016-12-01  27.15  17.31   27.33   83.97  125.44   0.0  4.04
# 9146  600856  2017-12-01  23.64  16.88   64.34   78.62   86.85   0.0  5.62
# 9147  600857  2014-12-01  11.15   2.86  156.46  -19.91    0.01   0.0  0.00
#
# ...

# %%
target_y = data['是否違約']

# %%
# 違約比率
len(np.where(target_y==1)[0])/len(target_y)
# Out:
# 0.013226934849147354

# %% [markdown]
# ## Preclude the redundant feature
# '財報年月','財報年月_r$','產業名','year','原因','delete','市場年度'

# %%
columns = data.columns.difference(['公司碼','財報年月','財報年月_r$','產業碼','產業名','year','上市板塊','原因','delete','是否違約','市場年度'])

# %%
data = data[columns]
data
# Out:
#        A105   A106    A116    A401    A509  A511  A517    A519   A609  \
# 0     29.94  14.65   69.29    9.03  101.74   0.0  1.08  101.74   6.20
# 1     28.66  14.50   63.30   31.97  113.69   0.0  0.97  113.69   4.12
# 2     28.90  14.23   63.86   23.41  144.92   0.0  0.97  144.92   3.48
# 3     33.71  18.75   77.07    0.73  189.57   0.0  1.69  189.57   2.65
# 4     37.14  22.77   72.33   22.60  215.13   0.0  2.78  215.13   1.86
# ...     ...    ...     ...     ...     ...   ...   ...     ...    ...
# 9143  24.48  20.10   50.70  235.27   78.80   0.0  3.09   78.80  30.00
# 9144  21.20  16.94   57.71   65.01   60.94   0.0  2.74   60.94  37.48
# 9145  27.15  17.31   27.33   83.97  125.44   0.0  4.04  125.44  40.40
# 9146  23.64  16.88   64.34   78.62   86.85   0.0  5.62   86.85  39.94
# 9147  11.15   2.86  156.46  -19.91    0.01   0.0  0.00    0.01   0.72
#
#          A611  ...  R903   R906   SUD1   T310  XCNL  XCPA   XCTL  XGRP   XMTG  \
# ...

# %% [markdown]
# ## 處理產業別
# 1. one-hot encoding
#     - 上市板塊
#     - 產業碼
#     - 公司(?)
# 2. 分群方法<br>
#     使用產業指數的日報酬率來計算彼此的距離(HRP)

# %%
# data_clean = pd.concat([data[columns],pd.get_dummies(data['上市板塊']),pd.get_dummies(data['產業碼'])], axis=1)
# data_clean

# %% [markdown]
# ## 標準化
# - 逐年標準化
# - 全體標準化

# %%
def standarize(x):
    return (x-np.mean(x))/np.std(x)

# %%
data_std = data.apply(standarize)
data_std
# Out:
#           A105      A106      A116      A401      A509      A511      A517  \
# 0     0.155906  0.010461 -0.401397 -0.046266  0.334499 -0.142139 -0.087050
# 1     0.082568  0.010461 -0.430237  0.006949  0.437604 -0.142139 -0.090957
# 2     0.096319  0.010461 -0.427540 -0.012908  0.707057 -0.142139 -0.090957
# 3     0.371911  0.010463 -0.363939 -0.065520  1.092298 -0.142139 -0.065388
# 4     0.568435  0.010464 -0.386761 -0.014787  1.312830 -0.142139 -0.026679
# ...        ...       ...       ...       ...       ...       ...       ...
# 9143 -0.156928  0.010463 -0.490901  0.478554  0.136572 -0.142139 -0.015670
# 9144 -0.344858  0.010462 -0.457150  0.083593 -0.017524 -0.142139 -0.028100
# 9145 -0.003949  0.010462 -0.603419  0.127576  0.538983 -0.142139  0.018066
# 9146 -0.205056  0.010462 -0.425229  0.115165  0.206028 -0.142139  0.074176
# 9147 -0.920679  0.010456  0.018294 -0.113400 -0.543229 -0.142139 -0.125404
#
# ...

# %%
data_std_y = pd.concat([data_std, target_y], axis=1)
data_std_y
# Out:
#           A105      A106      A116      A401      A509      A511      A517  \
# 0     0.155906  0.010461 -0.401397 -0.046266  0.334499 -0.142139 -0.087050
# 1     0.082568  0.010461 -0.430237  0.006949  0.437604 -0.142139 -0.090957
# 2     0.096319  0.010461 -0.427540 -0.012908  0.707057 -0.142139 -0.090957
# 3     0.371911  0.010463 -0.363939 -0.065520  1.092298 -0.142139 -0.065388
# 4     0.568435  0.010464 -0.386761 -0.014787  1.312830 -0.142139 -0.026679
# ...        ...       ...       ...       ...       ...       ...       ...
# 9143 -0.156928  0.010463 -0.490901  0.478554  0.136572 -0.142139 -0.015670
# 9144 -0.344858  0.010462 -0.457150  0.083593 -0.017524 -0.142139 -0.028100
# 9145 -0.003949  0.010462 -0.603419  0.127576  0.538983 -0.142139  0.018066
# 9146 -0.205056  0.010462 -0.425229  0.115165  0.206028 -0.142139  0.074176
# 9147 -0.920679  0.010456  0.018294 -0.113400 -0.543229 -0.142139 -0.125404
#
# ...

# %%
# con = sqlite3.connect("data_std.db")
# cur = con.cursor()
# # cur.execute(f'''create table credit_default_pred{tuple(data_std.columns)}''')
# # con.commit()
# data_std_y.to_sql('credit_default_pred', con, if_exists = 'replace', index=False)
# Out:
# 9148

# %% [markdown]
# ## train/test split
# test/train ratio = 0.3

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data_std, target_y, test_size=0.3, random_state=42)

# %% [markdown]
# ## SVM

# %%
from sklearn import svm
model_svm = svm.SVC()
model_svm.fit(X_train, y_train)
model_svm.score(X_train, y_train)
# Out:
# 0.9882867405903483

# %%
predict_y = model_svm.predict(X_train)
np.where(predict_y==1)
# Out:
# (array([ 487,  978, 1565, 2320, 5697, 5774, 5997], dtype=int64),)

# %% [markdown]
# ## Random Forest

# %%
# 設置max_depth 以防止 overfitting
rf = RandomForestClassifier(n_estimators = 1000 ,random_state=50,  max_depth = 10)
rf.fit(X_train, y_train)
rf_predict_y = rf.predict(X_train)
rf_predict_prob = rf.fit(X_train, y_train).predict_proba(X_train)
rf.score(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\2022011702\Desktop\Leo\Credit Default Predict\credit_default_predict.ipynb Cell 23 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/2022011702/Desktop/Leo/Credit%20Default%20Predict/credit_default_predict.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> # 設置max_depth 以防止 overfitting
#       <a href='vscode-notebook-cell:/c%3A/Users/2022011702/Desktop/Leo/Credit%20Default%20Predict/credit_default_predict.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> rf = RandomForestClassifier(n_estimators = 1000 ,random_state=50,  max_depth = 10)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/2022011702/Desktop/Leo/Credit%20Default%20Predict/credit_default_predict.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a> rf.fit(X_train, y_train)
# ...

# %%
rf_predict_prob
# Out:
# array([[9.98218297e-01, 1.78170280e-03],
#        [9.99194383e-01, 8.05616884e-04],
#        [9.97746995e-01, 2.25300462e-03],
#        ...,
#        [7.29657103e-01, 2.70342897e-01],
#        [9.83323973e-01, 1.66760267e-02],
#        [9.98458925e-01, 1.54107519e-03]])

# %%
confusion_matrix(y_train, rf_predict_y)
# Out:
# array([[6321,    0],
#        [  45,   37]], dtype=int64)

# %% [markdown]
# ## Model Evaluation
# - PCC
# - AUC
# - confusion matrix

# %%
def plot_roc_curve(y_train, y_predict):
    fpr, tpr, threshold = roc_curve(y_train, y_predict)
    print(fpr, tpr, threshold)
    auc1 = auc(fpr, tpr)
    ## Plot the result
    plt.figure(figsize=(10,6))
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, color = 'orange', label = 'AUC = %0.3f' % auc1)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([-0.01,1])
    plt.ylim([0,1.01])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
plot_roc_curve(y_train, predict_y)
# Out:
# [0. 0. 1.] [0.         0.08536585 1.        ] [2. 1. 0.]

# %%
plot_roc_curve(y_train, rf_predict_y)
# Out:
# [0. 0. 1.] [0.         0.45121951 1.        ] [2. 1. 0.]

# %%
def plot_confusion_matrix(y_train, y_predict):
    conf_matrix= confusion_matrix(y_train, y_predict)
    LABELS=['Non_Fraud','Fraud'] #給出類別名稱
    plt.figure(figsize=(8,8))
    sns.heatmap(conf_matrix,xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d")
    plt.title("Confusion Matrix")
    plt.ylabel("Predicted class")
    plt.xlabel("True class")
    plt.show()

# %%
plot_confusion_matrix(y_train, predict_y)

# %%
plot_confusion_matrix(y_train, rf_predict_y)
